# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
from keras.models import Sequential
from keras.layers import LSTM ,Dense, Dropout
from keras.optimizers import SGD, Adam

# %%
train_path = "C:/Users/Manali/Desktop/Study Material/datasets/archive/UCI_HAR_Dataset/train/"
test_path = "C:/Users/Manali/Desktop/Study Material/datasets/archive/UCI_HAR_Dataset/test/"
features_path = "C:/Users/Manali/Desktop/Study Material/datasets/archive/UCI_HAR_Dataset/features.txt"

# %% [markdown]
# # Features
# We need to extract features names from file features.txt

# %%
features = []
with open(features_path) as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
print("No. of unique features:{}".format(len(set(features))))
# Out:
# No of Features: 561
# No. of unique features:477

# %% [markdown]
# This shows that there are duplicate feature names

# %%
#LABELS
labels = {1: 'WALKING', 
          2:'WALKING_UPSTAIRS',
          3:'WALKING_DOWNSTAIRS',
          4:'SITTING',
          5:'STANDING',
          6:'LAYING'}

# %% [markdown]
# The names of features need to be processed. We need to replace () , "-" from their names.

# %%
re=[]
for i , f in enumerate(features):
    for j in range(i+1 , len(features)):
        if features[i]==features[j] and features[i] not in re:
            re.append(features[i])

# %%
for i , f in enumerate(features):
    features[i] = ''.join(e for e in f if e not in ['(',')' , '-' , ','])

# %% [markdown]
# pandas doesnt handle duplicate column names so its better you defined header=NONE and later set DataframeName.columns=[columnNames]

# %%
train = pd.read_csv(train_path + "X_train.txt" , delim_whitespace=True ,header=None)
train.columns = features
train['subject'] = pd.read_csv(train_path + 'subject_train.txt' , header=None , squeeze=True)
test = pd.read_csv(test_path + "X_test.txt" , delim_whitespace=True ,header=None)
test.columns = features
test['subject'] = pd.read_csv(test_path + 'subject_test.txt' , header=None , squeeze=True)

# %%
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    fBodyBodyGyroJerkMagskewness  fBodyBodyGyroJerkMagkurtosis  \
# 0                     -0.298676                     -0.710304
# 1                     -0.595051                     -0.861499
# 2                     -0.390748                     -0.760104
# 3                     -0.117290                     -0.482845
# 4                     -0.351471                     -0.699205
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
# 3                 -0.036788                         -0.012892
# 4                  0.123320                          0.122542
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
# 3                       0.640011                          -0.485366
# 4                       0.693578                          -0.615971
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject
# 0          -0.841247           0.179941          -0.058627        1
# 1          -0.844788           0.180289          -0.054317        1
# 2          -0.848933           0.180637          -0.049118        1
# 3          -0.848649           0.181935          -0.047663        1
# 4          -0.847865           0.185151          -0.043892        1
#
# [5 rows x 562 columns]

# %%
test.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1       0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2       0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3       0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4       0.274833      -0.027848      -0.129527     -0.993852     -0.967445
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.667683     -0.952501     -0.925249     -0.674302     -0.894088  ...
# 1     -0.944958     -0.986799     -0.968401     -0.945823     -0.894088  ...
# 2     -0.962748     -0.994403     -0.970735     -0.963483     -0.939260  ...
# 3     -0.967091     -0.995274     -0.974471     -0.968897     -0.938610  ...
# 4     -0.978295     -0.994111     -0.965953     -0.977346     -0.938610  ...
#
#    fBodyBodyGyroJerkMagskewness  fBodyBodyGyroJerkMagkurtosis  \
# 0                     -0.330370                     -0.705974
# 1                     -0.121845                     -0.594944
# 2                     -0.190422                     -0.640736
# 3                     -0.344418                     -0.736124
# 4                     -0.534685                     -0.846595
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                  0.006462                          0.162920
# 1                 -0.083495                          0.017500
# 2                 -0.034956                          0.202302
# 3                 -0.017067                          0.154438
# 4                 -0.002223                         -0.040046
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.825886                           0.271151
# 1                      -0.434375                           0.920593
# 2                       0.064103                           0.145068
# 3                       0.340134                           0.296407
# 4                       0.736715                          -0.118545
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject
# 0          -0.720009           0.276801          -0.057978        2
# 1          -0.698091           0.281343          -0.083898        2
# 2          -0.702771           0.280083          -0.079346        2
# 3          -0.698954           0.284114          -0.077108        2
# 4          -0.692245           0.290722          -0.073857        2
#
# [5 rows x 562 columns]

# %%
y_train = pd.read_csv(train_path + 'y_train.txt' , names=['Activity'] , squeeze=True)
y_test = pd.read_csv(test_path + 'y_test.txt' , names=['Activity'] , squeeze=True)

# %%
train['Activity']= y_train
test['Activity'] = y_test
train['ActivityName'] = y_train.map(labels)
test['ActivityName']  = y_test.map(labels)

# %% [markdown]
# # Data Analysis
# 1.Check for missing Values
#   2.Duplicate Values

# %%
print("The number of missing values in Training Data:" , train.isnull().values.sum())
print("The number of missing values in Testing Data:" , test.isnull().values.sum())
# Out:
# The number of missing values in Training Data: 0
# The number of missing values in Testing Data: 0

# %%
print("The number of duplicate values in Training Data:" , train.duplicated().sum())
print("The number of duplicate values in Testing Data:" , test.duplicated().sum())
# Out:
# The number of duplicate values in Training Data: 0
# The number of duplicate values in Testing Data: 0

# %% [markdown]
# 1. Data Imbalance

# %%
plt.figure(figsize=(10,5))
plt.title('Subject Wise Data Distribution')
sns.countplot(x='subject' , data=train )
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.title('Activity based Subject Distribution')
sns.countplot(x='subject' , hue='ActivityName', data=train )
plt.show()

# %% [markdown]
# Acceleration is not so important in activities like Standing, Sitting, Laying

# %%
accFeat=[]
for feat in features:
    if feat.find('BodyAcc') != -1 and feat.find('Magmean') !=-1 and feat.find('Freq')==-1:
        accFeat.append(feat)

# %%
def plotFacetGrid(feature, height):
    
    plt.figure(figsize=(10,10))
    facetgrid=sns.FacetGrid(train , hue='ActivityName',height=height,aspect=3)
    facetgrid.map(sns.distplot ,feature, hist=False).add_legend()
    plt.show()

# %%
for f in accFeat:
    plotFacetGrid(f,3)

# %%
def boxplot(feature , ylabel):
    
    plt.figure(figsize=(5,5))
    sns.boxplot(x='ActivityName', y=feature, data=train , showfliers=False )
    plt.ylabel(ylabel)
    plt.axhline(y=-0.8, xmin=0.1, xmax=0.9,dashes=(5,5), c='g') #line separating both type of activities
    plt.xticks(rotation=90)

# %%
for f in accFeat:
    boxplot(f , f[5:])

# %% [markdown]
# # Dimentionality Reduction using T-SNE

# %%
from sklearn.manifold import TSNE

# %%
def plotTsne(X,y,perplexity):
    
    #performing dim reduction
    X_reduce = TSNE(verbose=2, perplexity=perplexity).fit_transform(X)
    
    print('Creating plot for this t-sne visualization..')
    data={'x':X_reduce[:,0],
          'y':X_reduce[:,1],
         'label':y}
    #preparing dataframe from reduced data
    df = pd.DataFrame(data)
    
    #draw the plot
    sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
    
    plt.title("perplexity : {}".format(perplexity))
    img_name = 'TSNE_perp_{}.png'.format(perplexity)
    print('saving this plot as image in present working directory...')
    plt.savefig(img_name)
    plt.show()
    print('Done')

# %%
X= train.drop(['ActivityName'],axis=1)
y= train['ActivityName']
perplexity=[2,5,10]

# %%
for p in perplexity:
    plotTsne(X,y,perplexity=p)
# Out:
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 2.316s...
# [t-SNE] Computed neighbors for 7352 samples in 23.189s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.721133
# [t-SNE] Computed conditional probabilities in 0.098s
# [t-SNE] Iteration 50: error = 124.4965744, gradient norm = 0.0409314 (50 iterations in 4.920s)
# [t-SNE] Iteration 100: error = 104.6573639, gradient norm = 0.0303332 (50 iterations in 3.534s)
# [t-SNE] Iteration 150: error = 97.9992447, gradient norm = 0.0212687 (50 iterations in 3.149s)
# [t-SNE] Iteration 200: error = 94.1346588, gradient norm = 0.0175951 (50 iterations in 3.259s)
# [t-SNE] Iteration 250: error = 91.4371490, gradient norm = 0.0160866 (50 iterations in 3.070s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 91.437149
# [t-SNE] Iteration 300: error = 3.9989529, gradient norm = 0.0015488 (50 iterations in 3.256s)
# [t-SNE] Iteration 350: error = 3.0919530, gradient norm = 0.0010113 (50 iterations in 3.215s)
# [t-SNE] Iteration 400: error = 2.6589317, gradient norm = 0.0007163 (50 iterations in 3.375s)
# [t-SNE] Iteration 450: error = 2.3904855, gradient norm = 0.0005680 (50 iterations in 3.304s)
# [t-SNE] Iteration 500: error = 2.2034252, gradient norm = 0.0004855 (50 iterations in 3.351s)
# [t-SNE] Iteration 550: error = 2.0624917, gradient norm = 0.0004238 (50 iterations in 3.349s)
# [t-SNE] Iteration 600: error = 1.9508439, gradient norm = 0.0003708 (50 iterations in 3.111s)
# [t-SNE] Iteration 650: error = 1.8588649, gradient norm = 0.0003371 (50 iterations in 3.115s)
# [t-SNE] Iteration 700: error = 1.7811852, gradient norm = 0.0003073 (50 iterations in 3.324s)
# [t-SNE] Iteration 750: error = 1.7143495, gradient norm = 0.0002831 (50 iterations in 3.240s)
# [t-SNE] Iteration 800: error = 1.6561071, gradient norm = 0.0002611 (50 iterations in 3.141s)
# [t-SNE] Iteration 850: error = 1.6049786, gradient norm = 0.0002415 (50 iterations in 3.180s)
# [t-SNE] Iteration 900: error = 1.5590425, gradient norm = 0.0002269 (50 iterations in 3.187s)
# [t-SNE] Iteration 950: error = 1.5176913, gradient norm = 0.0002136 (50 iterations in 3.152s)
# [t-SNE] Iteration 1000: error = 1.4801893, gradient norm = 0.0002021 (50 iterations in 3.130s)
# [t-SNE] KL divergence after 1000 iterations: 1.480189
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 2.162s...
# [t-SNE] Computed neighbors for 7352 samples in 25.241s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.127482
# [t-SNE] Computed conditional probabilities in 0.122s
# [t-SNE] Iteration 50: error = 113.1369400, gradient norm = 0.0370243 (50 iterations in 4.086s)
# [t-SNE] Iteration 100: error = 92.9860153, gradient norm = 0.0191471 (50 iterations in 3.319s)
# [t-SNE] Iteration 150: error = 86.9399033, gradient norm = 0.0134689 (50 iterations in 3.219s)
# [t-SNE] Iteration 200: error = 83.5724869, gradient norm = 0.0112404 (50 iterations in 3.188s)
# [t-SNE] Iteration 250: error = 81.3442917, gradient norm = 0.0079910 (50 iterations in 3.184s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.344292
# [t-SNE] Iteration 300: error = 3.2611201, gradient norm = 0.0014418 (50 iterations in 3.201s)
# [t-SNE] Iteration 350: error = 2.4954453, gradient norm = 0.0007526 (50 iterations in 3.382s)
# [t-SNE] Iteration 400: error = 2.1030643, gradient norm = 0.0005373 (50 iterations in 2.858s)
# [t-SNE] Iteration 450: error = 1.8790092, gradient norm = 0.0004115 (50 iterations in 2.805s)
# [t-SNE] Iteration 500: error = 1.7302054, gradient norm = 0.0003340 (50 iterations in 3.206s)
# [t-SNE] Iteration 550: error = 1.6218772, gradient norm = 0.0002906 (50 iterations in 3.036s)
# [t-SNE] Iteration 600: error = 1.5381151, gradient norm = 0.0002537 (50 iterations in 3.053s)
# [t-SNE] Iteration 650: error = 1.4709982, gradient norm = 0.0002240 (50 iterations in 3.087s)
# [t-SNE] Iteration 700: error = 1.4155413, gradient norm = 0.0002025 (50 iterations in 3.100s)
# [t-SNE] Iteration 750: error = 1.3687708, gradient norm = 0.0001837 (50 iterations in 3.221s)
# [t-SNE] Iteration 800: error = 1.3284115, gradient norm = 0.0001711 (50 iterations in 3.126s)
# [t-SNE] Iteration 850: error = 1.2934221, gradient norm = 0.0001591 (50 iterations in 2.934s)
# [t-SNE] Iteration 900: error = 1.2626947, gradient norm = 0.0001481 (50 iterations in 3.160s)
# [t-SNE] Iteration 950: error = 1.2351875, gradient norm = 0.0001389 (50 iterations in 3.080s)
# [t-SNE] Iteration 1000: error = 1.2103534, gradient norm = 0.0001307 (50 iterations in 3.126s)
# [t-SNE] KL divergence after 1000 iterations: 1.210353
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 2.558s...
# [t-SNE] Computed neighbors for 7352 samples in 28.444s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.357802
# [t-SNE] Computed conditional probabilities in 0.212s
# [t-SNE] Iteration 50: error = 103.6784897, gradient norm = 0.0333073 (50 iterations in 4.035s)
# [t-SNE] Iteration 100: error = 84.1382370, gradient norm = 0.0136058 (50 iterations in 3.235s)
# [t-SNE] Iteration 150: error = 78.8778839, gradient norm = 0.0086285 (50 iterations in 3.163s)
# [t-SNE] Iteration 200: error = 76.0588989, gradient norm = 0.0071762 (50 iterations in 3.244s)
# [t-SNE] Iteration 250: error = 74.2101898, gradient norm = 0.0062771 (50 iterations in 3.279s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.210190
# [t-SNE] Iteration 300: error = 2.7170067, gradient norm = 0.0013904 (50 iterations in 3.286s)
# [t-SNE] Iteration 350: error = 2.0540209, gradient norm = 0.0006651 (50 iterations in 3.388s)
# [t-SNE] Iteration 400: error = 1.7134056, gradient norm = 0.0004352 (50 iterations in 3.396s)
# [t-SNE] Iteration 450: error = 1.5186774, gradient norm = 0.0003256 (50 iterations in 3.415s)
# [t-SNE] Iteration 500: error = 1.3953764, gradient norm = 0.0002593 (50 iterations in 3.300s)
# [t-SNE] Iteration 550: error = 1.3086073, gradient norm = 0.0002166 (50 iterations in 3.275s)
# [t-SNE] Iteration 600: error = 1.2438269, gradient norm = 0.0001861 (50 iterations in 3.411s)
# [t-SNE] Iteration 650: error = 1.1929653, gradient norm = 0.0001658 (50 iterations in 3.257s)
# [t-SNE] Iteration 700: error = 1.1517826, gradient norm = 0.0001472 (50 iterations in 3.256s)
# [t-SNE] Iteration 750: error = 1.1174362, gradient norm = 0.0001340 (50 iterations in 3.402s)
# [t-SNE] Iteration 800: error = 1.0886552, gradient norm = 0.0001237 (50 iterations in 3.205s)
# [t-SNE] Iteration 850: error = 1.0640267, gradient norm = 0.0001153 (50 iterations in 3.277s)
# [t-SNE] Iteration 900: error = 1.0427173, gradient norm = 0.0001094 (50 iterations in 3.538s)
# [t-SNE] Iteration 950: error = 1.0243819, gradient norm = 0.0001049 (50 iterations in 3.524s)
# [t-SNE] Iteration 1000: error = 1.0091387, gradient norm = 0.0000983 (50 iterations in 3.590s)
# [t-SNE] KL divergence after 1000 iterations: 1.009139
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# # LSTM MODEL

# %%
# It is a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

"-----------------------RAW DATA--------------------------------------"

# Raw data signals
# Signals are from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
     "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
path= "C:/Users/Manali/Desktop/Study Material/datasets/archive/UCI_HAR_Dataset/"

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

"----------------------------LOAD SIGNAL---------------------------------------------"

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = path+subset+'/Inertial Signals/'+signal+'_'+subset+'.txt'
        signals_data.append(
            _read_csv(filename).values
        ) 

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

"-------------------------CONFUSION MATRIX----------------------------------------------"
# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])


"----------------------------LOAD Y-------------------------------------------------------"



def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of 
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = path+subset+'/y_'+subset+'.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).values

"---------------------------------LOAD DATA---------------------------------------------"


def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test


"---------------------------------COUNT CLASSES--------------------------------------------"

# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 30
batch_size = 16
n_hidden = 32

# %%
# Loading the train and test data
import numpy as np
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                5376
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 198
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Training the model
model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=epochs)
# Out:
# Epoch 1/30
# 460/460 [==============================] - 68s 130ms/step - loss: 1.3332 - accuracy: 0.4374 - val_loss: 0.9689 - val_accuracy: 0.6094
# Epoch 2/30
# 460/460 [==============================] - 54s 118ms/step - loss: 0.8245 - accuracy: 0.6484 - val_loss: 0.7976 - val_accuracy: 0.7156
# Epoch 3/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.6197 - accuracy: 0.7765 - val_loss: 0.6982 - val_accuracy: 0.7733
# Epoch 4/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.4782 - accuracy: 0.8374 - val_loss: 0.5765 - val_accuracy: 0.8134
# Epoch 5/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.3740 - accuracy: 0.8820 - val_loss: 0.5598 - val_accuracy: 0.8446
# Epoch 6/30
# 460/460 [==============================] - 58s 125ms/step - loss: 0.3373 - accuracy: 0.8919 - val_loss: 0.5604 - val_accuracy: 0.8385
# Epoch 7/30
# 460/460 [==============================] - 54s 119ms/step - loss: 0.3108 - accuracy: 0.9031 - val_loss: 0.4445 - val_accuracy: 0.8748
# Epoch 8/30
# 460/460 [==============================] - 53s 115ms/step - loss: 0.2485 - accuracy: 0.9219 - val_loss: 0.4364 - val_accuracy: 0.8724
# Epoch 9/30
# 460/460 [==============================] - 57s 124ms/step - loss: 0.2214 - accuracy: 0.9260 - val_loss: 0.4660 - val_accuracy: 0.8799
# Epoch 10/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.1930 - accuracy: 0.9372 - val_loss: 0.3715 - val_accuracy: 0.9040
# Epoch 11/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.1918 - accuracy: 0.9371 - val_loss: 0.3779 - val_accuracy: 0.9033
# Epoch 12/30
# 460/460 [==============================] - 57s 124ms/step - loss: 0.1800 - accuracy: 0.9369 - val_loss: 0.3642 - val_accuracy: 0.9114
# Epoch 13/30
# 460/460 [==============================] - 57s 125ms/step - loss: 0.1918 - accuracy: 0.9379 - val_loss: 0.4439 - val_accuracy: 0.8955
# Epoch 14/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.1632 - accuracy: 0.9387 - val_loss: 0.4090 - val_accuracy: 0.8968
# Epoch 15/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.1578 - accuracy: 0.9469 - val_loss: 0.4232 - val_accuracy: 0.9060
# Epoch 16/30
# 460/460 [==============================] - 57s 123ms/step - loss: 0.1741 - accuracy: 0.9400 - val_loss: 0.3973 - val_accuracy: 0.9080
# Epoch 17/30
# 460/460 [==============================] - 56s 121ms/step - loss: 0.1644 - accuracy: 0.9431 - val_loss: 0.3450 - val_accuracy: 0.9104
# Epoch 18/30
# 460/460 [==============================] - 55s 119ms/step - loss: 0.1539 - accuracy: 0.9451 - val_loss: 0.3937 - val_accuracy: 0.9077
# Epoch 19/30
# 460/460 [==============================] - 56s 122ms/step - loss: 0.1540 - accuracy: 0.9438 - val_loss: 0.4003 - val_accuracy: 0.9063
# Epoch 20/30
# 460/460 [==============================] - 59s 128ms/step - loss: 0.1549 - accuracy: 0.9445 - val_loss: 0.4105 - val_accuracy: 0.9043
# Epoch 21/30
# 460/460 [==============================] - 58s 126ms/step - loss: 0.1509 - accuracy: 0.9487 - val_loss: 0.4045 - val_accuracy: 0.9016
# Epoch 22/30
# 460/460 [==============================] - 60s 131ms/step - loss: 0.1689 - accuracy: 0.9454 - val_loss: 0.3461 - val_accuracy: 0.9101
# Epoch 23/30
# 460/460 [==============================] - 48s 104ms/step - loss: 0.1465 - accuracy: 0.9505 - val_loss: 0.4519 - val_accuracy: 0.9063
# Epoch 24/30
# 460/460 [==============================] - 54s 118ms/step - loss: 0.1431 - accuracy: 0.9428 - val_loss: 0.3792 - val_accuracy: 0.9175
# Epoch 25/30
# 460/460 [==============================] - 60s 131ms/step - loss: 0.1432 - accuracy: 0.9461 - val_loss: 0.4097 - val_accuracy: 0.9006
# Epoch 26/30
# 460/460 [==============================] - 45s 98ms/step - loss: 0.1302 - accuracy: 0.9431 - val_loss: 0.5611 - val_accuracy: 0.9023
# Epoch 27/30
# 460/460 [==============================] - 13s 27ms/step - loss: 0.1556 - accuracy: 0.9452 - val_loss: 0.6567 - val_accuracy: 0.8985
# Epoch 28/30
# 460/460 [==============================] - 16s 36ms/step - loss: 0.1468 - accuracy: 0.9451 - val_loss: 0.5239 - val_accuracy: 0.9043
# Epoch 29/30
# 460/460 [==============================] - 17s 36ms/step - loss: 0.1355 - accuracy: 0.9479 - val_loss: 0.4110 - val_accuracy: 0.9148
# Epoch 30/30
# 460/460 [==============================] - 16s 36ms/step - loss: 0.1341 - accuracy: 0.9485 - val_loss: 0.5216 - val_accuracy: 0.9141
